# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_url ='./datagiuaki1.csv'
df=pd.read_csv(data_url, encoding='unicode_escape')
df
# Out:
#                     team  wins  losses  goals  total_yel_card  total_red_card  \
# 0      Manchester United    28       4     68              61               5
# 1                Chelsea    25       5     68              50               3
# 2              Liverpool    25       2     77              50               0
# 3                Arsenal    20       6     68              58               3
# 4            Aston Villa    17      10     54              54               2
# 5                Everton    17       9     55              49               1
# 6        Manchester City    15      18     58              49               4
# 7                 Fulham    14      13     39              40               1
# 8      Tottenham Hotspur    14      15     45              54               5
# 9        West Ham United    14      15     42              66               4
# 10            Stoke City    12      17     38              73               5
# ...

# %%
df_sorted = df.sort_values(by='wins', ascending=False)
plt.barh(top_5_teams['team'], top_5_teams['wins'])
plt.title('Top 5 đội bóng với số lần thắng nhiều nhất')
plt.xlabel('Số lần thắng')
plt.ylabel('Đội')
plt.show()
